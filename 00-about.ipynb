# %% [markdown]
# # PYT101 - Introduction to programming with Python
# ## About this workshop
#
# The workshop material is adapted from the tutorial
# [Software Carpentry - Programming with Python](https://swcarpentry.github.io/python-novice-inflammation/) and of [Introduction to High-Performance Computing in Python](https://www.hpc-carpentry.org/hpc-python/).
#
# Note: the *notebooks* used in this workshop and the corresponding data are [published on GitHub](https://github.com/calculquebec/PYT101-2025).

# %% [markdown]
# ### How to Use Jupyter
# When a cell is in edit mode:
#
#   Shortcut  | Description
# ----------- | -----------
# Shift+Enter | Run the cell, and go to the next
# Tab         | Indent code or auto-completion
# Esc         | Go to command mode
#
# When a cell is in command mode:
#
#   Shortcut   | Description
# ------------ | -----------
# Shift+Enter  | Run the cell, and go to the next
# Double-click | Go to edit mode
# Enter        | Go to edit mode
#
#   Shortcut   | Description
# ------------ | -----------
# A            | Insert a cell above
# B            | Insert a cell below
# C            | Copy the current cell
# V            | Paste the cell below
# D D          | Delete the current cell
# M            | Change to Markdown cell
# Y            | Change to Code cell
#
# To reset all cells:
# * Go to the top menu, and select Kernel -> Restart & Clear Output
